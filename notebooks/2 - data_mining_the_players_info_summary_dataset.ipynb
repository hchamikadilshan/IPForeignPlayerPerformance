# %%
import pandas as pd

# %%
player_info_summary_dataset = pd.read_csv("../datasets/players_info_summary_new.csv")

# %%
without_indian_players =  player_info_summary_dataset[player_info_summary_dataset["country"] != "India"]

# %%
without_indian_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 1 to 730
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   player_id             392 non-null    int64
#  1   player_name           392 non-null    object
#  2   country               332 non-null    object
#  3   played_international  322 non-null    object
#  4   bowling_style         351 non-null    object
#  5   batting_style         373 non-null    object
#  6   player_role           332 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 24.5+ KB

# %%
played_international =  without_indian_players.dropna(subset=["played_international"])

# %%
played_international
# Out:
#      player_id      player_name       country played_international  \
# 1            2      BB McCullum   New Zealand          2002 - 2016
# 2            3       RT Ponting     Australia          1995 - 2012
# 3            4        DJ Hussey     Australia          2008 - 2013
# 4            5  Mohammad Hafeez      Pakistan          2003 - 2021
# 8            9        JH Kallis  South Africa          1995 - 2014
# ..         ...              ...           ...                  ...
# 720        721       SSB Magala  South Africa          2021 - 2023
# 725        726         N Burger  South Africa          2023 - 2024
# 726        727       KT Maphaka  South Africa          2024 - 2025
# 729        730         S Joseph   West Indies          2024 - 2024
# 730        731       N Thushara     Sri Lanka          2022 - 2025
#
#                             bowling_style   batting_style          player_role
# 1    Right arm Medium, Right arm Offbreak  Right hand Bat  Wicketkeeper Batter
# ...

# %%
played_international.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 322 entries, 1 to 730
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   player_id             322 non-null    int64
#  1   player_name           322 non-null    object
#  2   country               319 non-null    object
#  3   played_international  322 non-null    object
#  4   bowling_style         303 non-null    object
#  5   batting_style         322 non-null    object
#  6   player_role           319 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 20.1+ KB

# %%
players_with_country_na = played_international[played_international["country"].isna()]
players_with_country_na
# Out:
#      player_id  player_name country played_international  \
# 59          60    SB Bangar     NaN          2001 - 2004
# 78          79    VRV Singh     NaN          2006 - 2007
# 219        220  RS Gavaskar     NaN          2004 - 2004
#
#               bowling_style   batting_style player_role
# 59    Right arm Medium fast  Right hand Bat         NaN
# 78    Right arm Medium fast  Right hand Bat         NaN
# 219  Slow Left arm Orthodox   Left hand Bat         NaN

# %% [markdown]
# - All 3 above players are Indian Players. So They will be removed

# %%
cleaned_played_international = played_international.dropna(subset=["country"])
cleaned_played_international.info()
cleaned_played_international
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 319 entries, 1 to 730
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   player_id             319 non-null    int64
#  1   player_name           319 non-null    object
#  2   country               319 non-null    object
#  3   played_international  319 non-null    object
#  4   bowling_style         300 non-null    object
#  5   batting_style         319 non-null    object
#  6   player_role           319 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 19.9+ KB
#      player_id      player_name       country played_international  \
# 1            2      BB McCullum   New Zealand          2002 - 2016
# 2            3       RT Ponting     Australia          1995 - 2012
# 3            4        DJ Hussey     Australia          2008 - 2013
# 4            5  Mohammad Hafeez      Pakistan          2003 - 2021
# ...

# %%
bowling_style_na =  cleaned_played_international[cleaned_played_international["bowling_style"].isna()]
bowling_style_na
# Out:
#      player_id    player_name       country played_international  \
# 42          43       L Ronchi   New Zealand          2008 - 2018
# 69          70   Kamran Akmal      Pakistan          2002 - 2017
# 107        108     SP Fleming   New Zealand          1994 - 2008
# 279        280      BJ Haddin     Australia          2001 - 2015
# 288        289      M Klinger     Australia          2017 - 2017
# 341        342    MDKJ Perera     Sri Lanka          2013 - 2025
# 353        354      BJ Rohrer     Australia          2013 - 2013
# 355        356      Q de Kock  South Africa          2012 - 2024
# 407        408     JC Buttler       England          2011 - 2024
# 421        422    SW Billings       England          2015 - 2022
# 423        424  PSP Handscomb     Australia          2016 - 2023
# 438        439         JJ Roy       England          2014 - 2023
# 461        462        E Lewis   West Indies          2016 - 2024
# ...

# %% [markdown]
# - All the players with bowling style missing are batters.

# %%
cleaned_played_international.to_csv('../datasets/international_played_foreign_players.csv', index=False)
